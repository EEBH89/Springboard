# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
# View properties dataframe
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
# Transpose dataframe so boroughs are the indices
properties = properties.transpose()
properties.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
# Set first row as column header
col_names = properties.iloc[0]
properties = properties[1:]
properties.columns = col_names
properties.head()
# Out:
# Unnamed: 0                NaT 1995-01-01 1995-02-01 1995-03-01 1995-04-01  \
# City of London      E09000001      91449    82202.8    79120.7    77101.2
# Barking & Dagenham  E09000002    50460.2    51085.8      51269    53133.5
# Barnet              E09000003    93284.5    93190.2    92247.5    90762.9
# Bexley              E09000004    64958.1    64787.9    64367.5    64277.7
# Brent               E09000005    71306.6    72022.3    72015.8    72965.6
#
# Unnamed: 0         1995-05-01 1995-06-01 1995-07-01 1995-08-01 1995-09-01  \
# City of London        84409.1    94900.5     110128     112329     104473
# Barking & Dagenham    53042.2    53700.3    52113.1    52232.2    51471.6
# Barnet                  90258    90107.2    91441.2    92361.3    93273.1
# Bexley                63997.1    64252.3    63722.7    64432.6    64509.5
# Brent                   73704    74310.5      74127      73547    73789.5
#
# Unnamed: 0          ... 2019-05-01 2019-06-01 2019-07-01 2019-08-01  \
# ...

# %%
# reset index so borough names are not indices
properties = properties.reset_index()
properties.head()
# Out:
# Unnamed: 0               index        NaN 1995-01-01 00:00:00  \
# 0               City of London  E09000001               91449
# 1           Barking & Dagenham  E09000002             50460.2
# 2                       Barnet  E09000003             93284.5
# 3                       Bexley  E09000004             64958.1
# 4                        Brent  E09000005             71306.6
#
# Unnamed: 0 1995-02-01 00:00:00 1995-03-01 00:00:00 1995-04-01 00:00:00  \
# 0                      82202.8             79120.7             77101.2
# 1                      51085.8               51269             53133.5
# 2                      93190.2             92247.5             90762.9
# 3                      64787.9             64367.5             64277.7
# 4                      72022.3             72015.8             72965.6
#
# Unnamed: 0 1995-05-01 00:00:00 1995-06-01 00:00:00 1995-07-01 00:00:00  \
# 0                      84409.1             94900.5              110128
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# rename borough and ID columns
properties = properties.rename(columns={'index':'boroughs', pd.NaT: 'ID'})
properties.head()
# Out:
# Unnamed: 0            boroughs         ID 1995-01-01 00:00:00  \
# 0               City of London  E09000001               91449
# 1           Barking & Dagenham  E09000002             50460.2
# 2                       Barnet  E09000003             93284.5
# 3                       Bexley  E09000004             64958.1
# 4                        Brent  E09000005             71306.6
#
# Unnamed: 0 1995-02-01 00:00:00 1995-03-01 00:00:00 1995-04-01 00:00:00  \
# 0                      82202.8             79120.7             77101.2
# 1                      51085.8               51269             53133.5
# 2                      93190.2             92247.5             90762.9
# 3                      64787.9             64367.5             64277.7
# 4                      72022.3             72015.8             72965.6
#
# Unnamed: 0 1995-05-01 00:00:00 1995-06-01 00:00:00 1995-07-01 00:00:00  \
# 0                      84409.1             94900.5              110128
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# Get list of columns names, not including borough and ID
month_col_names = properties.columns[2:304]
print(month_col_names)
# Out:
# Index([1995-01-01 00:00:00, 1995-02-01 00:00:00, 1995-03-01 00:00:00,
#        1995-04-01 00:00:00, 1995-05-01 00:00:00, 1995-06-01 00:00:00,
#        1995-07-01 00:00:00, 1995-08-01 00:00:00, 1995-09-01 00:00:00,
#        1995-10-01 00:00:00,
#        ...
#        2019-05-01 00:00:00, 2019-06-01 00:00:00, 2019-07-01 00:00:00,
#        2019-08-01 00:00:00, 2019-09-01 00:00:00, 2019-10-01 00:00:00,
#        2019-11-01 00:00:00, 2019-12-01 00:00:00, 2020-01-01 00:00:00,
#        2020-02-01 00:00:00],
#       dtype='object', name='Unnamed: 0', length=302)

# %%
# use month_col_names to melt dataframe
properties_m = pd.melt(properties, id_vars = ['boroughs', 'ID'], value_vars=month_col_names, value_name='average price', var_name="month")
properties_m.tail(10)
# Out:
#                  boroughs         ID      month average price
# 14486          NORTH WEST  E12000002 2020-02-01        163602
# 14487  YORKS & THE HUMBER  E12000003 2020-02-01        162334
# 14488       EAST MIDLANDS  E12000004 2020-02-01        192244
# 14489       WEST MIDLANDS  E12000005 2020-02-01        198658
# 14490     EAST OF ENGLAND  E12000006 2020-02-01        286869
# 14491              LONDON  E12000007 2020-02-01        476972
# 14492          SOUTH EAST  E12000008 2020-02-01        321329
# 14493          SOUTH WEST  E12000009 2020-02-01        258044
# 14494         Unnamed: 47        NaN 2020-02-01           NaN
# 14495             England  E92000001 2020-02-01        246341

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
# check data types of columns
properties_m['average price']
properties_m['month']
# Out:
# 0       1995-01-01
# 1       1995-01-01
# 2       1995-01-01
# 3       1995-01-01
# 4       1995-01-01
#            ...
# 14491   2020-02-01
# 14492   2020-02-01
# 14493   2020-02-01
# 14494   2020-02-01
# 14495   2020-02-01
# Name: month, Length: 14496, dtype: datetime64[ns]

# %%
# Change average price column from object to floating point
properties_m['average price'] = properties_m['average price'].astype(float)
properties_m['average price']
# Out:
# 0         91448.98487
# 1         50460.22660
# 2         93284.51832
# 3         64958.09036
# 4         71306.56698
#              ...
# 14491    476972.07330
# 14492    321329.36450
# 14493    258043.97170
# 14494             NaN
# 14495    246341.31270
# Name: average price, Length: 14496, dtype: float64

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
# check for empty entries
properties_m.count()
# Out:
# boroughs         14496
# ID               13590
# month            14496
# average price    13590
# dtype: int64

# %%
# check borough names
properties_m['boroughs'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
# explore what is in the unnamed borough rows
properties_m[properties_m['boroughs']=='Unnamed: 47']
# Out:
#           boroughs   ID      month  average price
# 46     Unnamed: 47  NaN 1995-01-01            NaN
# 94     Unnamed: 47  NaN 1995-02-01            NaN
# 142    Unnamed: 47  NaN 1995-03-01            NaN
# 190    Unnamed: 47  NaN 1995-04-01            NaN
# 238    Unnamed: 47  NaN 1995-05-01            NaN
# ...            ...  ...        ...            ...
# 14302  Unnamed: 47  NaN 2019-10-01            NaN
# 14350  Unnamed: 47  NaN 2019-11-01            NaN
# 14398  Unnamed: 47  NaN 2019-12-01            NaN
# 14446  Unnamed: 47  NaN 2020-01-01            NaN
# 14494  Unnamed: 47  NaN 2020-02-01            NaN
#
# [302 rows x 4 columns]

# %%
# Boroughs with unnamed have nan entries, drop them
properties_clean = properties_m[properties_m['average price'].notna()]
properties_clean.count()
# Out:
# boroughs         13590
# ID               13590
# month            13590
# average price    13590
# dtype: int64

# %%
# recheck borough names
properties_clean['boroughs'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
# identify and list non-borough names, filter dataframe to drop those, check boroughs again
invalid_boroughs=['Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS','EAST OF ENGLAND', 'LONDON', 'SOUTH EAST','SOUTH WEST', 'England']

properties_clean = properties_clean[~properties_clean['boroughs'].isin(invalid_boroughs)]
properties_clean['boroughs'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster'], dtype=object)

# %%
len(properties_clean['boroughs'].unique())
# Out:
# 33

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
# subset for borough = Lambeth, plot
properties_clean[properties_clean['boroughs']=='Lambeth'].plot(x='month', y='average price', kind='line')
plt.show()

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# create year column
properties_clean['year'] = properties_clean['month'].apply(lambda t:t.year)
properties_clean.head()

# group by borough and year, with mean of average price, reset index
df = properties_clean.groupby(by=['boroughs', 'year']).mean()
df= df.reset_index()
df.head()
# Out:
#              boroughs  year  average price
# 0  Barking & Dagenham  1995   51817.969390
# 1  Barking & Dagenham  1996   51718.192690
# 2  Barking & Dagenham  1997   55974.262309
# 3  Barking & Dagenham  1998   60285.821083
# 4  Barking & Dagenham  1999   65320.934441

# %%
# explore general trends of each borough as groups
df_p = properties_clean.groupby(by=['boroughs', 'year']).mean()
df_p = df_p.reset_index()


b_groups = df_p.groupby('boroughs')

fig, ax = plt.subplots()
for name, group in b_groups:
    ax.plot(group['year'], group['average price'])

plt.show()

# %%
# identify least expensive borough in 2020, 1995

df_sorted = df_p[df_p['year'] == 1995].sort_values('average price')
df_sorted.head(20)

# least expensive borough is Barking & Dagenham $300,000 in 2020
# Out:
#                boroughs  year  average price
# 0    Barking & Dagenham  1995   51817.969390
# 624              Newham  1995   54574.226405
# 572            Lewisham  1995   58881.766015
# 780      Waltham Forest  1995   61279.980463
# 260           Greenwich  1995   63389.786578
# 754       Tower Hamlets  1995   63652.446010
# 702           Southwark  1995   64260.053745
# 52               Bexley  1995   64291.532845
# 286             Hackney  1995   66024.476545
# 546             Lambeth  1995   68105.691318
# 390            Havering  1995   68281.012730
# 182             Croydon  1995   68923.340845
# 728              Sutton  1995   70291.304638
# 234             Enfield  1995   71984.234888
# 650           Redbridge  1995   72580.490579
# 442            Hounslow  1995   72941.170845
# 78                Brent  1995   73029.841840
# 416          Hillingdon  1995   73755.756008
# 338            Haringey  1995   80078.489250
# 598              Merton  1995   80500.752648

# %%
#identify most expensive borough

df_sorted = df_p[df_p['year'] == 2020].sort_values('average price', ascending=False)
df_sorted.head(20)

# most expensive borough is Kensington & Chelsea 1.2 million in 2020
# Out:
#                  boroughs  year  average price
# 519  Kensington & Chelsea  2020   1.243997e+06
# 857           Westminster  2020   9.866469e+05
# 155                Camden  2020   7.967989e+05
# 181        City of London  2020   7.393695e+05
# 337  Hammersmith & Fulham  2020   7.354963e+05
# 493             Islington  2020   6.772722e+05
# 701  Richmond upon Thames  2020   6.699334e+05
# 831            Wandsworth  2020   6.019907e+05
# 311               Hackney  2020   5.713471e+05
# 363              Haringey  2020   5.455664e+05
# 571               Lambeth  2020   5.275914e+05
# 51                 Barnet  2020   5.221472e+05
# 727             Southwark  2020   5.020737e+05
# 623                Merton  2020   4.991406e+05
# 545  Kingston upon Thames  2020   4.957326e+05
# 233                Ealing  2020   4.690044e+05
# 779         Tower Hamlets  2020   4.612660e+05
# 103                 Brent  2020   4.525746e+05
# 389                Harrow  2020   4.462026e+05
# ...

# %%
df_p[df_p['boroughs']== 'Hackney']
# Out:
#     boroughs  year  average price
# 286  Hackney  1995   66024.476545
# 287  Hackney  1996   69247.652452
# 288  Hackney  1997   78176.799825
# 289  Hackney  1998   87869.535804
# 290  Hackney  1999  105532.969242
# 291  Hackney  2000  132727.506075
# 292  Hackney  2001  153406.324217
# 293  Hackney  2002  180269.456333
# 294  Hackney  2003  201071.484342
# 295  Hackney  2004  217677.077825
# 296  Hackney  2005  227936.951650
# 297  Hackney  2006  253254.400458
# 298  Hackney  2007  290396.712150
# 299  Hackney  2008  311770.527550
# 300  Hackney  2009  282240.752267
# 301  Hackney  2010  300490.890992
# 302  Hackney  2011  308698.435383
# 303  Hackney  2012  325492.483900
# 304  Hackney  2013  372668.901533
# 305  Hackney  2014  456388.443458
# 306  Hackney  2015  506798.991100
# 307  Hackney  2016  537746.346433
# 308  Hackney  2017  549005.563992
# 309  Hackney  2018  544640.475027
# 310  Hackney  2019  554908.617867
# 311  Hackney  2020  571347.093350

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear inmind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
# create price ratio function for 1998 to 2018

def price_ratio(arg):
    avg_price_98 = float(arg['average price'][arg['year'] == 1998])
    avg_price_18 = float(arg['average price'][arg['year'] == 2018])
    ratio = avg_price_18 / avg_price_98
    return ratio

# test function

test = price_ratio(df[df['boroughs']=='Lambeth'])
print(test)
# Out:
# 4.957751163514063

# %%
# run price ratio function over df for new dataframe

ratios = {}

for item in df['boroughs'].unique():
    borough = df[df['boroughs']==item]
    ratio = price_ratio(borough)
    ratios[item] = ratio
    
print(ratios)
# Out:
# {'Barking & Dagenham': 4.89661861291754, 'Barnet': 4.358195917538044, 'Bexley': 4.248977046127877, 'Brent': 4.8945544971392865, 'Bromley': 4.0947846853338765, 'Camden': 4.935353408884261, 'City of London': 5.301620377587609, 'Croydon': 4.201100280024767, 'Ealing': 4.311450902121834, 'Enfield': 4.26347158349581, 'Greenwich': 4.763036347329193, 'Hackney': 6.198285561008662, 'Hammersmith & Fulham': 4.137798101936229, 'Haringey': 5.134624964136042, 'Harrow': 4.0591964329643195, 'Havering': 4.325230371335308, 'Hillingdon': 4.2002730803844575, 'Hounslow': 3.976409106143329, 'Islington': 4.844048012802298, 'Kensington & Chelsea': 5.082465066092464, 'Kingston upon Thames': 4.270549521484271, 'Lambeth': 4.957751163514063, 'Lewisham': 5.449221041059685, 'Merton': 4.741273313294604, 'Newham': 5.305390437201879, 'Redbridge': 4.471182006097364, 'Richmond upon Thames': 4.005161895721457, 'Southwark': 5.516485302379376, 'Sutton': 4.118522608573157, 'Tower Hamlets': 4.62670104006116, 'Waltham Forest
# ...

# %%
# turn ratios dict into dataframe

df=pd.DataFrame([ratios])
df.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon    Ealing   Enfield  ...    Merton   Newham  \
# 0         5.30162   4.2011  4.311451  4.263472  ...  4.741273  5.30539
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.471182              4.005162   5.516485  4.118523       4.626701
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.834756    4.757709     5.353565
#
# [1 rows x 33 columns]

# %%
# transpose 

df = df.transpose()
df.head()
# Out:
#                            0
# Barking & Dagenham  4.896619
# Barnet              4.358196
# Bexley              4.248977
# Brent               4.894554
# Bromley             4.094785

# %%
# reset index
df=df.reset_index()
df.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
# rename columns
df.rename(columns={'index': 'borough', 0:'price ratio'}, inplace=True) 
df.head()
# Out:
#               borough  price ratio
# 0  Barking & Dagenham     4.896619
# 1              Barnet     4.358196
# 2              Bexley     4.248977
# 3               Brent     4.894554
# 4             Bromley     4.094785

# %%
df.sort_values(by='price ratio', ascending = False)
# Out:
#                  borough  price ratio
# 11               Hackney     6.198286
# 30        Waltham Forest     5.834756
# 27             Southwark     5.516485
# 22              Lewisham     5.449221
# 32           Westminster     5.353565
# 24                Newham     5.305390
# 6         City of London     5.301620
# 13              Haringey     5.134625
# 19  Kensington & Chelsea     5.082465
# 21               Lambeth     4.957751
# 5                 Camden     4.935353
# 0     Barking & Dagenham     4.896619
# 3                  Brent     4.894554
# 18             Islington     4.844048
# 10             Greenwich     4.763036
# 31            Wandsworth     4.757709
# 23                Merton     4.741273
# 29         Tower Hamlets     4.626701
# 25             Redbridge     4.471182
# 1                 Barnet     4.358196
# 15              Havering     4.325230
# 8                 Ealing     4.311451
# 20  Kingston upon Thames     4.270550
# 9                Enfield     4.263472
# ...

# %%
#top 10 increasing boroughs
top_ten = df.sort_values(by='price ratio', ascending = False).loc[:21]

top_ten
# Out:
#                  borough  price ratio
# 11               Hackney     6.198286
# 30        Waltham Forest     5.834756
# 27             Southwark     5.516485
# 22              Lewisham     5.449221
# 32           Westminster     5.353565
# 24                Newham     5.305390
# 6         City of London     5.301620
# 13              Haringey     5.134625
# 19  Kensington & Chelsea     5.082465
# 21               Lambeth     4.957751

# %%
top_ten.plot(kind='bar').set_xticklabels(top_ten['borough'])
plt.show()

# %%
ls= list(top_ten['borough'])
print(ls)
# Out:
# ['Hackney', 'Waltham Forest', 'Southwark', 'Lewisham', 'Westminster', 'Newham', 'City of London', 'Haringey', 'Kensington & Chelsea', 'Lambeth', 'Camden', 'Barking & Dagenham', 'Brent', 'Islington', 'Greenwich']

# %%
# create new variable to describe percent change from 1998 to 2018

def percent_chg(arg):
    avg_price_98 = float(arg['average price'][arg['year'] == 1998])
    avg_price_18 = float(arg['average price'][arg['year'] == 2018])
    chg = (avg_price_18 - avg_price_98) / avg_price_98 *100
    return chg

# test function

test = percent_chg(df_p[df_p['boroughs']=='Lambeth'])
print(test)
# Out:
# 395.77511635140627

# %%
# run percent change function over df for new dataframe

pchange = {}

for item in df_p['boroughs'].unique():
    borough = df_p[df_p['boroughs']==item]
    change = percent_chg(borough)
    pchange[item] = change
    
print(pchange)
# Out:
# {'Barking & Dagenham': 389.66186129175395, 'Barnet': 335.8195917538044, 'Bexley': 324.8977046127876, 'Brent': 389.4554497139287, 'Bromley': 309.4784685333876, 'Camden': 393.53534088842605, 'City of London': 430.1620377587609, 'Croydon': 320.1100280024768, 'Ealing': 331.14509021218345, 'Enfield': 326.3471583495809, 'Greenwich': 376.30363473291925, 'Hackney': 519.8285561008662, 'Hammersmith & Fulham': 313.77981019362295, 'Haringey': 413.4624964136042, 'Harrow': 305.9196432964319, 'Havering': 332.52303713353075, 'Hillingdon': 320.0273080384457, 'Hounslow': 297.64091061433294, 'Islington': 384.40480128022983, 'Kensington & Chelsea': 408.2465066092464, 'Kingston upon Thames': 327.05495214842705, 'Lambeth': 395.77511635140627, 'Lewisham': 444.9221041059684, 'Merton': 374.1273313294604, 'Newham': 430.5390437201879, 'Redbridge': 347.1182006097364, 'Richmond upon Thames': 300.5161895721457, 'Southwark': 451.6485302379376, 'Sutton': 311.8522608573157, 'Tower Hamlets': 362.67010400611605, 'Walt
# ...

# %%
# turn ratios dict into dataframe

df_2=pd.DataFrame([pchange])
df_2 = df_2.transpose()
df_2=df_2.reset_index()
df_2.head()
# Out:
#                 index           0
# 0  Barking & Dagenham  389.661861
# 1              Barnet  335.819592
# 2              Bexley  324.897705
# 3               Brent  389.455450
# 4             Bromley  309.478469

# %%
# rename columns
df_2 = df_2.rename(columns=({'index':'borough', 0:'percent change'}))
df_2.head()
# Out:
#               borough  percent change
# 0  Barking & Dagenham      389.661861
# 1              Barnet      335.819592
# 2              Bexley      324.897705
# 3               Brent      389.455450
# 4             Bromley      309.478469

# %%
# sort

df_2 = df_2.sort_values('percent change', ascending = False)
df_2.head(10)
# Out:
#                  borough  percent change
# 11               Hackney      519.828556
# 30        Waltham Forest      483.475581
# 27             Southwark      451.648530
# 22              Lewisham      444.922104
# 32           Westminster      435.356539
# 24                Newham      430.539044
# 6         City of London      430.162038
# 13              Haringey      413.462496
# 19  Kensington & Chelsea      408.246507
# 21               Lambeth      395.775116

# %%
#plot top ten

top_ten_2 = df_2.loc[:21]

ax = top_ten_2.plot(kind='bar', title='London Boroughs with Largest Change in Housing Prices', legend=False).set_xticklabels(top_ten['borough'])
plt.ylabel('Percent Change 1998-2018')
plt.show()

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# Conclusions:
#
# Housing prices in London boroughs have been increasing since the 1990's. These boroughs have seen the most increase in average price between 1998 and 2018:
#
# Hackney, Waltham Forest, Southwark, Lewisham, Westminster, Newham, City of London, Haringey, Kensington & Chelsea, Lambeth
#
# The least expensive borough in 1995 remained the least expensive borough in 2020, Barking & Dagenham which currently sees average prices of $300,000. The same can be said for the most expensive borough Kensington & Chelsea with average price of 1.2 million in 2020.
#
# In general, boroughs followed similar trends over time including peaks in prices around 2006/2007 followed by severe drops in prices around 2008/2009, likley attributed to the recession associated with the US financial crisis. Prices then recovered and continued to climb steadily until leveling off around 2016/2017.
#
# Each of the 33 boroughs evaluated saw prices increase by at least 297%. Hackney borough saw the most increase over the last two decades, with average prices increasing by more than 500% ($87,870 to $544,640).
